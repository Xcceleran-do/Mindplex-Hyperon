# %% [markdown]
# # Pipeline demo (placeholder)
# This notebook will show end-to-end steps: project graph, run GraphSAGE, compute text embeddings, assemble vectors, train ranker.

# %%
print('Hello from pipeline demo notebook')
